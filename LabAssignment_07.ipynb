# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51LA0/NLP/blob/main/LabAssignment_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Sample dataset
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# (a) Data Preprocessing
def preprocess_data(data):
    # Split English and French sentences
    eng_texts = [pair[0] for pair in data]
    fra_texts = ['<start> ' + pair[1] + ' <end>' for pair in data]

    # Create tokenizers
    eng_tokenizer = Tokenizer()
    fra_tokenizer = Tokenizer()

    # Fit tokenizers
    eng_tokenizer.fit_on_texts(eng_texts)
    fra_tokenizer.fit_on_texts(fra_texts)

    # Convert texts to sequences
    eng_sequences = eng_tokenizer.texts_to_sequences(eng_texts)
    fra_sequences = fra_tokenizer.texts_to_sequences(fra_texts)

    # Find maximum lengths
    max_eng_len = max(len(seq) for seq in eng_sequences)
    max_fra_len = max(len(seq) for seq in fra_sequences)

    # Pad sequences
    eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
    fra_padded = pad_sequences(fra_sequences, maxlen=max_fra_len, padding='post')

    return eng_padded, fra_padded, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len

# Process the data
eng_data, fra_data, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len = preprocess_data(data)

# Get vocabulary sizes
eng_vocab_size = len(eng_tokenizer.word_index) + 1
fra_vocab_size = len(fra_tokenizer.word_index) + 1

# Print shapes for debugging
print("Input shapes:")
print(f"English data shape: {eng_data.shape}")
print(f"French data shape: {fra_data.shape}")

# (b) Build Seq2Seq Model
def build_model(input_vocab, output_vocab, input_length, output_length):
    # Encoder
    encoder_inputs = Input(shape=(input_length,))
    encoder_embedding = Embedding(input_vocab, 50)(encoder_inputs)
    encoder = LSTM(100, return_state=True)
    encoder_outputs, state_h, state_c = encoder(encoder_embedding)
    encoder_states = [state_h, state_c]

    # Decoder
    decoder_inputs = Input(shape=(output_length,))
    decoder_embedding = Embedding(output_vocab, 50)(decoder_inputs)
    decoder_lstm = LSTM(100, return_sequences=True)
    decoder_outputs = decoder_lstm(decoder_embedding, initial_state=encoder_states)
    decoder_dense = Dense(output_vocab, activation='softmax')
    decoder_outputs = decoder_dense(decoder_outputs)

    # Create model
    model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
    return model

# (c) Prepare Data for Training
decoder_input_data = fra_data[:, :-1]  # Remove last token
decoder_target_data = fra_data[:, 1:]  # Remove first token

# Print shapes for debugging
print("\nTraining data shapes:")
print(f"Decoder input shape: {decoder_input_data.shape}")
print(f"Decoder target shape: {decoder_target_data.shape}")

# (d) Train the Model
model = build_model(
    eng_vocab_size,
    fra_vocab_size,
    max_eng_len,
    max_fra_len - 1
)

# Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    [eng_data, decoder_input_data],
    decoder_target_data,
    batch_size=2,
    epochs=100,
    validation_split=0.2
)

# (e) Inference Setup
class Translator:
    def __init__(self, model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len): # Changed _init_ to __init__
        self.model = model
        self.eng_tokenizer = eng_tokenizer
        self.fra_tokenizer = fra_tokenizer
        self.max_eng_len = max_eng_len
        self.max_fra_len = max_fra_len
        self.fra_index_word = {v: k for k, v in fra_tokenizer.word_index.items()}

    def translate(self, text):
        # Tokenize input text
        sequence = self.eng_tokenizer.texts_to_sequences([text])
        padded = pad_sequences(sequence, maxlen=self.max_eng_len, padding='post')

        # Initialize target sequence
        target_seq = np.zeros((1, self.max_fra_len - 1))

        # Generate translation
        prediction = self.model.predict([padded, target_seq])

        # Convert prediction to text
        output_sequence = np.argmax(prediction[0], axis=1)
        translated_text = []

        for idx in output_sequence:
            if idx != 0:
                word = self.fra_index_word.get(idx, '')
                if word and word not in ['<start>', '<end>']:
                    translated_text.append(word)

        return ' '.join(translated_text)
# (f) Translate New Sentences
translator = Translator(model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len)

# Test translations
test_sentences = [
    "hello",
    "thank you",
    "your name",
    "how are you"
]

print("\nTranslations:")
for sentence in test_sentences:
    translation = translator.translate(sentence)
    print(f"English: {sentence}")
    print(f"French: {translation}\n")
# Out:
# Input shapes:
# English data shape: (7, 4)
# French data shape: (7, 5)
#
# Training data shapes:
# Decoder input shape: (7, 4)
# Decoder target shape: (7, 4)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 292ms/step - accuracy: 0.0656 - loss: 2.7734 - val_accuracy: 0.5000 - val_loss: 2.7585
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4656 - loss: 2.7540 - val_accuracy: 0.5000 - val_loss: 2.7429
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3313 - loss: 2.7384 - val_accuracy: 0.6250 - val_loss: 2.7278
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3313 - loss: 2.7176 - val_accuracy: 0.5000 - val_loss: 2.7069
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3938 - loss: 2.6844 - val_accuracy: 0.5000 - val_loss: 2.6770
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2500 - loss: 2.6611 - val_accuracy: 0.3750 - val_loss: 2.6373
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2500 - loss: 2.5985 - val_accuracy: 0.2500 - val_loss: 2.5725
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2500 - loss: 2.5495 - val_accuracy: 0.2500 - val_loss: 2.4798
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2500 - loss: 2.4218 - val_accuracy: 0.2500 - val_loss: 2.3358
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2500 - loss: 2.2513 - val_accuracy: 0.2500 - val_loss: 2.1860
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2500 - loss: 2.0784 - val_accuracy: 0.2500 - val_loss: 2.1742
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2500 - loss: 2.0480 - val_accuracy: 0.2500 - val_loss: 2.1607
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2500 - loss: 2.0924 - val_accuracy: 0.2500 - val_loss: 2.1114
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2500 - loss: 2.0809 - val_accuracy: 0.6250 - val_loss: 2.0952
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3313 - loss: 1.9760 - val_accuracy: 0.6250 - val_loss: 2.1016
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3719 - loss: 2.0143 - val_accuracy: 0.6250 - val_loss: 2.1157
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3719 - loss: 1.9648 - val_accuracy: 0.6250 - val_loss: 2.1334
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4281 - loss: 1.8541 - val_accuracy: 0.6250 - val_loss: 2.1672
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5063 - loss: 1.6663 - val_accuracy: 0.6250 - val_loss: 2.2312
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5469 - loss: 1.6537 - val_accuracy: 0.6250 - val_loss: 2.3006
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5312 - loss: 1.6314 - val_accuracy: 0.6250 - val_loss: 2.3578
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5719 - loss: 1.4869 - val_accuracy: 0.6250 - val_loss: 2.4164
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5813 - loss: 1.6574 - val_accuracy: 0.6250 - val_loss: 2.4904
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5969 - loss: 1.4715 - val_accuracy: 0.5000 - val_loss: 2.5949
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5969 - loss: 1.4847 - val_accuracy: 0.5000 - val_loss: 2.7396
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6438 - loss: 1.2004 - val_accuracy: 0.5000 - val_loss: 2.8822
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6219 - loss: 1.3329 - val_accuracy: 0.5000 - val_loss: 3.0016
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6531 - loss: 1.1561 - val_accuracy: 0.5000 - val_loss: 3.1249
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7406 - loss: 1.0155 - val_accuracy: 0.5000 - val_loss: 3.2333
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6781 - loss: 1.0590 - val_accuracy: 0.5000 - val_loss: 3.3412
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7344 - loss: 0.9329 - val_accuracy: 0.5000 - val_loss: 3.4352
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8687 - loss: 0.7849 - val_accuracy: 0.5000 - val_loss: 3.5140
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7750 - loss: 0.8434 - val_accuracy: 0.5000 - val_loss: 3.6124
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8062 - loss: 0.7266 - val_accuracy: 0.5000 - val_loss: 3.7314
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9500 - loss: 0.5447 - val_accuracy: 0.5000 - val_loss: 3.8486
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9594 - loss: 0.5890 - val_accuracy: 0.5000 - val_loss: 3.9148
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9281 - loss: 0.5617 - val_accuracy: 0.5000 - val_loss: 3.9603
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9594 - loss: 0.4216 - val_accuracy: 0.5000 - val_loss: 4.0652
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9281 - loss: 0.4668 - val_accuracy: 0.5000 - val_loss: 4.1605
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9281 - loss: 0.3920 - val_accuracy: 0.5000 - val_loss: 4.2270
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9594 - loss: 0.3008 - val_accuracy: 0.5000 - val_loss: 4.2700
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.3340 - val_accuracy: 0.5000 - val_loss: 4.3052
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.2679 - val_accuracy: 0.5000 - val_loss: 4.3394
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.2349 - val_accuracy: 0.5000 - val_loss: 4.3979
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.2460 - val_accuracy: 0.5000 - val_loss: 4.4185
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.2117 - val_accuracy: 0.5000 - val_loss: 4.4777
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.1776 - val_accuracy: 0.5000 - val_loss: 4.5028
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.1637 - val_accuracy: 0.5000 - val_loss: 4.5351
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.1638 - val_accuracy: 0.5000 - val_loss: 4.5884
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.1430 - val_accuracy: 0.5000 - val_loss: 4.6583
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.1218 - val_accuracy: 0.5000 - val_loss: 4.6871
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.1289 - val_accuracy: 0.5000 - val_loss: 4.7137
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.1024 - val_accuracy: 0.5000 - val_loss: 4.7367
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.1142 - val_accuracy: 0.5000 - val_loss: 4.7384
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0974 - val_accuracy: 0.5000 - val_loss: 4.7882
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0942 - val_accuracy: 0.5000 - val_loss: 4.8499
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0886 - val_accuracy: 0.5000 - val_loss: 4.8344
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0772 - val_accuracy: 0.5000 - val_loss: 4.8245
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0809 - val_accuracy: 0.5000 - val_loss: 4.8735
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0716 - val_accuracy: 0.5000 - val_loss: 4.9496
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.1011 - val_accuracy: 0.5000 - val_loss: 4.8906
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0658 - val_accuracy: 0.5000 - val_loss: 4.8609
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0615 - val_accuracy: 0.5000 - val_loss: 4.8612
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0631 - val_accuracy: 0.5000 - val_loss: 4.8942
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0541 - val_accuracy: 0.5000 - val_loss: 4.9325
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0550 - val_accuracy: 0.5000 - val_loss: 4.9623
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0519 - val_accuracy: 0.5000 - val_loss: 4.9623
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0539 - val_accuracy: 0.5000 - val_loss: 4.9379
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0491 - val_accuracy: 0.5000 - val_loss: 4.9435
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0484 - val_accuracy: 0.5000 - val_loss: 4.9739
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0456 - val_accuracy: 0.5000 - val_loss: 5.0037
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0409 - val_accuracy: 0.5000 - val_loss: 5.0209
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0377 - val_accuracy: 0.5000 - val_loss: 5.0215
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0359 - val_accuracy: 0.5000 - val_loss: 5.0189
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0358 - val_accuracy: 0.5000 - val_loss: 5.0239
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0382 - val_accuracy: 0.5000 - val_loss: 5.0382
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0348 - val_accuracy: 0.5000 - val_loss: 5.0554
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0343 - val_accuracy: 0.5000 - val_loss: 5.0699
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0305 - val_accuracy: 0.5000 - val_loss: 5.0794
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0303 - val_accuracy: 0.5000 - val_loss: 5.0830
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0307 - val_accuracy: 0.5000 - val_loss: 5.0900
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0289 - val_accuracy: 0.5000 - val_loss: 5.1023
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 0.5000 - val_loss: 5.1143
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0278 - val_accuracy: 0.5000 - val_loss: 5.1249
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0255 - val_accuracy: 0.5000 - val_loss: 5.1324
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0249 - val_accuracy: 0.5000 - val_loss: 5.1367
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 0.5000 - val_loss: 5.1404
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0250 - val_accuracy: 0.5000 - val_loss: 5.1460
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0251 - val_accuracy: 0.5000 - val_loss: 5.1554
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 0.5000 - val_loss: 5.1664
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 0.5000 - val_loss: 5.1759
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0228 - val_accuracy: 0.5000 - val_loss: 5.1834
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0222 - val_accuracy: 0.5000 - val_loss: 5.1895
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 0.5000 - val_loss: 5.1947
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0208 - val_accuracy: 0.5000 - val_loss: 5.2003
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.5000 - val_loss: 5.2068
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 0.5000 - val_loss: 5.2133
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.5000 - val_loss: 5.2213
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.5000 - val_loss: 5.2277
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.5000 - val_loss: 5.2340
#
# Translations:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# English: hello
# French: bonjour end
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# English: thank you
# French: bonjour
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# English: your name
# French: je m'appelle
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# English: how are you
# French: comment ça va end
