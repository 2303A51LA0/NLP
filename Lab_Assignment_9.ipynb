# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51LA0/NLP/blob/main/Lab_Assignment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical

# Parameters
batch_size = 64
epochs = 100
latent_dim = 256
input_vocab_size = 100  # adjust based on actual vocab size
target_vocab_size = 100  # adjust based on actual vocab size

# Sample data (use your own dataset)
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# Vocabulary creation
input_texts = [pair[0] for pair in data]
target_texts = [pair[1] for pair in data]

# Create a mapping of unique tokens for both input and target sequences
input_tokens = sorted(set(" ".join(input_texts).split()))
target_tokens = sorted(set(" ".join(target_texts).split()))

input_token_index = dict([(char, i + 1) for i, char in enumerate(input_tokens)])
target_token_index = dict([(char, i + 1) for i, char in enumerate(target_tokens)])

input_vocab_size = len(input_token_index) + 1
target_vocab_size = len(target_token_index) + 1

# Encode sentences into sequences of integers
def encode_text(text, token_index, max_len):
    sequence = [token_index[word] for word in text.split() if word in token_index]
    sequence = sequence + [0] * (max_len - len(sequence))  # Pad sequences
    return sequence

# Determine maximum lengths for padding
max_encoder_seq_length = max([len(text.split()) for text in input_texts])
max_decoder_seq_length = max([len(text.split()) for text in target_texts])

# Prepare the data
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length), dtype="int32")
decoder_input_data = np.zeros((len(target_texts), max_decoder_seq_length), dtype="int32")
decoder_target_data = np.zeros((len(target_texts), max_decoder_seq_length, target_vocab_size), dtype="float32")

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    encoder_input_data[i] = encode_text(input_text, input_token_index, max_encoder_seq_length)
    decoder_input_data[i] = encode_text(target_text, target_token_index, max_decoder_seq_length)
    for t, word in enumerate(target_text.split()):
        if word in target_token_index:
            decoder_target_data[i, t, target_token_index[word]] = 1.0
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[word]] = 1.0  # Shifts the target sequence

# Model definition
# Encoder
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(input_dim=input_vocab_size, output_dim=latent_dim)(encoder_inputs)
encoder_outputs, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(input_dim=target_vocab_size, output_dim=latent_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(target_vocab_size, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer=RMSprop(), loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2
)

# Inference models
# Encoder model for inference
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model for inference
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_embedding, initial_state=decoder_states_inputs
)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

# Translation function
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1))
    start_token_index = 1 if target_token_index else 0  # Default to 0 if empty
    target_seq[0, 0] = start_token_index

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        reverse_target_token_index = dict((i, char) for char, i in target_token_index.items())
        sampled_word = reverse_target_token_index[sampled_token_index]
        decoded_sentence += ' ' + sampled_word

        # Exit condition: either hit max length or find stop character.
        if (sampled_word == '\n' or len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence.strip()

# Test the translation
test_input_seq = np.array(encode_text("hello", input_token_index, max_encoder_seq_length)).reshape(1, -1)
translated_sentence = decode_sequence(test_input_seq)
print("Translated sentence:", translated_sentence)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0667 - loss: 3.3467 - val_accuracy: 0.0000e+00 - val_loss: 1.7774
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step - accuracy: 0.5333 - loss: 3.2985 - val_accuracy: 0.0000e+00 - val_loss: 1.7933
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.6000 - loss: 3.2569 - val_accuracy: 0.0000e+00 - val_loss: 1.8095
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6000 - loss: 3.2144 - val_accuracy: 0.0000e+00 - val_loss: 1.8275
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.6000 - loss: 3.1680 - val_accuracy: 0.0000e+00 - val_loss: 1.8485
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.6000 - loss: 3.1152 - val_accuracy: 0.0000e+00 - val_loss: 1.8736
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6000 - loss: 3.0538 - val_accuracy: 0.0000e+00 - val_loss: 1.9041
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.5333 - loss: 2.9817 - val_accuracy: 0.0000e+00 - val_loss: 1.9415
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.5333 - loss: 2.8963 - val_accuracy: 0.0000e+00 - val_loss: 1.9873
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.4667 - loss: 2.7951 - val_accuracy: 0.0000e+00 - val_loss: 2.0432
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4667 - loss: 2.6761 - val_accuracy: 0.0000e+00 - val_loss: 2.1098
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.4667 - loss: 2.5381 - val_accuracy: 0.0000e+00 - val_loss: 2.1860
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4667 - loss: 2.3818 - val_accuracy: 0.0000e+00 - val_loss: 2.2684
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4667 - loss: 2.2111 - val_accuracy: 0.0000e+00 - val_loss: 2.3518
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.4667 - loss: 2.0338 - val_accuracy: 0.0000e+00 - val_loss: 2.4315
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4667 - loss: 1.8607 - val_accuracy: 0.0000e+00 - val_loss: 2.5073
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4667 - loss: 1.7014 - val_accuracy: 0.0000e+00 - val_loss: 2.5847
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5333 - loss: 1.5604 - val_accuracy: 0.0000e+00 - val_loss: 2.6744
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.5333 - loss: 1.4378 - val_accuracy: 0.0000e+00 - val_loss: 2.7911
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5333 - loss: 1.3318 - val_accuracy: 0.0000e+00 - val_loss: 2.9527
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5333 - loss: 1.2393 - val_accuracy: 0.0000e+00 - val_loss: 3.1815
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5333 - loss: 1.1574 - val_accuracy: 0.0000e+00 - val_loss: 3.5035
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5333 - loss: 1.0837 - val_accuracy: 0.0000e+00 - val_loss: 3.9404
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5333 - loss: 1.0154 - val_accuracy: 0.0000e+00 - val_loss: 4.4863
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5333 - loss: 0.9519 - val_accuracy: 0.0000e+00 - val_loss: 5.1888
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.6000 - loss: 0.9640 - val_accuracy: 0.0000e+00 - val_loss: 5.7838
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5333 - loss: 1.3852 - val_accuracy: 0.0000e+00 - val_loss: 5.9704
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 0.9825 - val_accuracy: 0.0000e+00 - val_loss: 6.5003
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4667 - loss: 0.8899 - val_accuracy: 0.0000e+00 - val_loss: 7.1388
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 0.8497 - val_accuracy: 0.0000e+00 - val_loss: 7.6994
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6000 - loss: 0.8586 - val_accuracy: 0.0000e+00 - val_loss: 7.9233
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.4667 - loss: 0.8517 - val_accuracy: 0.0000e+00 - val_loss: 8.1421
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6000 - loss: 0.8627 - val_accuracy: 0.0000e+00 - val_loss: 8.5293
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4667 - loss: 0.7817 - val_accuracy: 0.0000e+00 - val_loss: 9.0040
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5333 - loss: 0.8165 - val_accuracy: 0.0000e+00 - val_loss: 9.1350
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5333 - loss: 0.7898 - val_accuracy: 0.0000e+00 - val_loss: 9.9228
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4667 - loss: 0.9376 - val_accuracy: 0.0000e+00 - val_loss: 10.2452
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5333 - loss: 0.9344 - val_accuracy: 0.0000e+00 - val_loss: 9.8482
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.4667 - loss: 0.7957 - val_accuracy: 0.0000e+00 - val_loss: 10.1604
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5333 - loss: 0.7876 - val_accuracy: 0.0000e+00 - val_loss: 10.5047
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5333 - loss: 0.7701 - val_accuracy: 0.0000e+00 - val_loss: 10.7665
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5333 - loss: 0.7742 - val_accuracy: 0.0000e+00 - val_loss: 11.1017
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 0.7634 - val_accuracy: 0.0000e+00 - val_loss: 11.2607
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6667 - loss: 0.7716 - val_accuracy: 0.0000e+00 - val_loss: 11.6806
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4667 - loss: 0.7643 - val_accuracy: 0.0000e+00 - val_loss: 11.6635
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6667 - loss: 0.7710 - val_accuracy: 0.0000e+00 - val_loss: 12.1943
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.4667 - loss: 0.7668 - val_accuracy: 0.0000e+00 - val_loss: 11.9835
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6000 - loss: 0.7534 - val_accuracy: 0.0000e+00 - val_loss: 12.7328
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.4667 - loss: 0.7767 - val_accuracy: 0.0000e+00 - val_loss: 12.0038
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5333 - loss: 0.7664 - val_accuracy: 0.0000e+00 - val_loss: 12.9488
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.6000 - loss: 0.7749 - val_accuracy: 0.0000e+00 - val_loss: 12.7581
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4667 - loss: 0.7565 - val_accuracy: 0.0000e+00 - val_loss: 13.3666
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.6000 - loss: 0.7511 - val_accuracy: 0.0000e+00 - val_loss: 12.9764
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4667 - loss: 0.7502 - val_accuracy: 0.0000e+00 - val_loss: 13.8849
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6000 - loss: 0.7478 - val_accuracy: 0.0000e+00 - val_loss: 13.0519
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.4667 - loss: 0.7481 - val_accuracy: 0.0000e+00 - val_loss: 14.2641
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.6000 - loss: 0.7502 - val_accuracy: 0.0000e+00 - val_loss: 13.2786
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.4667 - loss: 0.7491 - val_accuracy: 0.0000e+00 - val_loss: 14.5828
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 0.7467 - val_accuracy: 0.0000e+00 - val_loss: 13.5735
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.4667 - loss: 0.7507 - val_accuracy: 0.0000e+00 - val_loss: 14.9873
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.4667 - loss: 0.7411 - val_accuracy: 0.0000e+00 - val_loss: 13.8610
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.4667 - loss: 0.7553 - val_accuracy: 0.0000e+00 - val_loss: 15.3484
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4667 - loss: 0.7376 - val_accuracy: 0.0000e+00 - val_loss: 14.1624
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.4667 - loss: 0.7523 - val_accuracy: 0.0000e+00 - val_loss: 15.6484
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4667 - loss: 0.7364 - val_accuracy: 0.0000e+00 - val_loss: 14.4235
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.4667 - loss: 0.7455 - val_accuracy: 0.0000e+00 - val_loss: 16.3478
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4667 - loss: 0.7432 - val_accuracy: 0.0000e+00 - val_loss: 15.2210
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 0.7367 - val_accuracy: 0.0000e+00 - val_loss: 16.0324
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4667 - loss: 0.7651 - val_accuracy: 0.0000e+00 - val_loss: 15.9730
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5333 - loss: 0.7381 - val_accuracy: 0.0000e+00 - val_loss: 16.6745
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4667 - loss: 0.7354 - val_accuracy: 0.0000e+00 - val_loss: 15.9436
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5333 - loss: 0.7483 - val_accuracy: 0.0000e+00 - val_loss: 17.7544
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.4667 - loss: 0.7286 - val_accuracy: 0.0000e+00 - val_loss: 16.9025
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.4667 - loss: 0.7302 - val_accuracy: 0.0000e+00 - val_loss: 17.3492
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4667 - loss: 0.7343 - val_accuracy: 0.0000e+00 - val_loss: 17.2095
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.4667 - loss: 0.7221 - val_accuracy: 0.0000e+00 - val_loss: 17.7750
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.4667 - loss: 0.7287 - val_accuracy: 0.0000e+00 - val_loss: 17.3103
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.4667 - loss: 0.7191 - val_accuracy: 0.0000e+00 - val_loss: 18.0315
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4667 - loss: 0.7263 - val_accuracy: 0.0000e+00 - val_loss: 17.7517
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4667 - loss: 0.7189 - val_accuracy: 0.0000e+00 - val_loss: 18.1526
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4667 - loss: 0.7189 - val_accuracy: 0.0000e+00 - val_loss: 18.3345
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4667 - loss: 0.7219 - val_accuracy: 0.0000e+00 - val_loss: 18.1591
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.4667 - loss: 0.7145 - val_accuracy: 0.0000e+00 - val_loss: 18.7486
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4667 - loss: 0.7240 - val_accuracy: 0.0000e+00 - val_loss: 18.3280
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.4667 - loss: 0.7066 - val_accuracy: 0.0000e+00 - val_loss: 18.7322
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.4667 - loss: 0.7229 - val_accuracy: 0.0000e+00 - val_loss: 18.5273
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4667 - loss: 0.7039 - val_accuracy: 0.0000e+00 - val_loss: 18.7587
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4667 - loss: 0.7204 - val_accuracy: 0.0000e+00 - val_loss: 18.7004
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.4667 - loss: 0.7012 - val_accuracy: 0.0000e+00 - val_loss: 18.7403
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.4667 - loss: 0.7169 - val_accuracy: 0.0000e+00 - val_loss: 18.8351
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.4000 - loss: 0.6984 - val_accuracy: 0.0000e+00 - val_loss: 18.6713
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.5333 - loss: 0.7144 - val_accuracy: 0.0000e+00 - val_loss: 18.9006
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.4000 - loss: 0.6956 - val_accuracy: 0.0000e+00 - val_loss: 18.5978
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.5333 - loss: 0.7144 - val_accuracy: 0.0000e+00 - val_loss: 18.8127
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.4000 - loss: 0.6961 - val_accuracy: 0.0000e+00 - val_loss: 18.5880
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.5333 - loss: 0.7194 - val_accuracy: 0.0000e+00 - val_loss: 18.5206
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.4000 - loss: 0.7047 - val_accuracy: 0.0000e+00 - val_loss: 18.5299
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.5333 - loss: 0.7066 - val_accuracy: 0.0000e+00 - val_loss: 18.6368
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.4000 - loss: 0.6944 - val_accuracy: 0.0000e+00 - val_loss: 18.3726
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 0.6940 - val_accuracy: 0.0000e+00 - val_loss: 18.5370
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78b3f49c5900> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Translated sentence: bonjour
